# %%
from collections import *
from typing import List
import bisect

# %% [markdown]
# 704.
# Binary Search
# Given an array of integers nums which is sorted in ascending order, and an integer target, write a function to search target in nums. If target exists, then return its index. Otherwise, return -1.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [-1,0,3,5,9,12], target = 9
# Output: 4
# Explanation: 9 exists in nums and its index is 4
# Example 2:
#
# Input: nums = [-1,0,3,5,9,12], target = 2
# Output: -1
# Explanation: 2 does not exist in nums so return -1
#
#
# Constraints:
#
# 1 <= nums.length <= 104
# -104 < nums[i], target < 104
# All the integers in nums are unique.
# nums is sorted in ascending order.

# %%
class Solution:
    def search(self, nums: [int], target: int) -> int:
        # return self.solution1(nums, target)
        # return self.solution2(nums, target)
        return self.solution3(nums, target)
    
    def solution1(self, nums, target):
        return bisect.bisect_left(nums, target) if target in nums else -1
    
    def solution2(self, nums, target):
        return self.binary_search(nums, target, 0, len(nums) - 1)
    
    def binary_search(self, nums, target, start, end):
        if start > end:
            return - 1
        mid = (start + end) // 2
        if nums[mid] == target:
            return mid 
        elif nums[mid] > target:
            return self.binary_search(nums, target, start, mid - 1)
        else:
            return self.binary_search(nums, target, mid + 1, end)
    
    def solution3(self, nums, target):
        '''
        Use while loop instead of recursion.
        Make sure the range is smaller after each iteration.
        '''
        start, end = 0, len(nums) - 1
        while start <= end:
            mid = (start + end) // 2
            if nums[mid] == target:
                return mid 
            elif nums[mid] > target:
                end = mid - 1
            else:
                start = mid + 1
        return -1

# %%
nums = [-1,0,3,5,9,12]
target = 2
Solution().search(nums, target)
# Out:
# -1

# %% [markdown]
# 875.
# Koko Eating Bananas
# Koko loves to eat bananas. There are n piles of bananas, the ith pile has piles[i] bananas. The guards have gone and will come back in h hours.
#
# Koko can decide her bananas-per-hour eating speed of k. Each hour, she chooses some pile of bananas and eats k bananas from that pile. If the pile has less than k bananas, she eats all of them instead and will not eat any more bananas during this hour.
#
# Koko likes to eat slowly but still wants to finish eating all the bananas before the guards return.
#
# Return the minimum integer k such that she can eat all the bananas within h hours.
#
#
#
# Example 1:
#
# Input: piles = [3,6,7,11], h = 8
# Output: 4
# Example 2:
#
# Input: piles = [30,11,23,4,20], h = 5
# Output: 30
# Example 3:
#
# Input: piles = [30,11,23,4,20], h = 6
# Output: 23
#
#
# Constraints:
#
# 1 <= piles.length <= 104
# piles.length <= h <= 109
# 1 <= piles[i] <= 109

# %%
class Solution:
    def minEatingSpeed(self, piles: [int], h: int) -> int:
        best_k = 1
        r = max(piles)
        l = 1
        while l <= r:
            k = (l + r) // 2
            hours = 0
            for pile in piles:
                hour = pile // k
                if pile % k:
                    hour += 1
                hours += hour 
            if hours <= h:
                best_k = k 
                r = k - 1
            else:
                l = k + 1
        
        return best_k

# %%
piles = [30,11,23,4,20]
h = 6
Solution().minEatingSpeed(piles, h)
# Out:
# 23

# %% [markdown]
# 34.
# Find First and Last Position of Element in Sorted Array
# Given an array of integers nums sorted in non-decreasing order, find the starting and ending position of a given target value.
#
# If target is not found in the array, return [-1, -1].
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [5,7,7,8,8,10], target = 8
# Output: [3,4]
# Example 2:
#
# Input: nums = [5,7,7,8,8,10], target = 6
# Output: [-1,-1]
# Example 3:
#
# Input: nums = [], target = 0
# Output: [-1,-1]
#
#
# Constraints:
#
# 0 <= nums.length <= 105
# -109 <= nums[i] <= 109
# nums is a non-decreasing array.
# -109 <= target <= 109

# %%
class Solution:
    '''
    Use additional LeftBorder and RightBorder to store data in the process
    '''
    def searchRange(self, nums: [int], target: int) -> [int]:
        n = len(nums)
        leftBorder, rightBorder = self.find_first(nums, target), self.find_last(nums, target)
        if leftBorder == -2:
            return -1, -1
        return leftBorder, rightBorder

    def find_first(self, nums, target):
        l, r = 0, len(nums) - 1
        leftBorder = -2
        while l <= r:
            mid = (l + r) // 2
            num = nums[mid]
            if target > num:
                l = mid + 1
            elif target < num:
                r = mid - 1
            elif target == num:
                r = mid - 1
                leftBorder = mid 
        return leftBorder
    
    def find_last(self, nums, target):
        l, r = 0, len(nums) - 1
        rightBorder = -2
        while l <= r:
            mid = (l + r) // 2
            num = nums[mid]
            if target == num:
                l = mid + 1
                rightBorder = mid 
            elif target > num:
                l = mid + 1
            else:
                r = mid - 1
        return rightBorder

# %%
nums = [5,7,7,8,8,10]
target = 6
Solution().searchRange(nums, target)
# Out:
# (-1, -1)

# %%
class Solution:
    ''' 
    Justify the last left or right one
    '''
    def searchRange(self, nums: [int], target: int) -> [int]:
        n = len(nums)
        return [self.find_first(nums, target), self.find_last(nums, target)]
        
    def find_first(self, nums, target):
        l, r = 0, len(nums) - 1
        while l <= r:
            mid = (l + r) // 2
            num = nums[mid]
            if target == num:
                r = mid - 1 #激进策略
            elif target < num:
                r = mid - 1
            else:
                l = mid + 1
        if r + 1 < len(nums) and nums[r + 1] == target: # 判断右边一个是不是
            return r + 1
        return -1
    
    def find_last(self, nums, target):
        l, r = 0, len(nums) - 1
        while l <= r:
            mid = (l + r) // 2
            num = nums[mid]
            if target == num:
                l = mid + 1
            elif target < num:
                r = mid - 1
            else:
                l = mid + 1
        if l > 0 and nums[l-1] == target:
            return l - 1
        return -1

# %%
class Solution:
    ''' 
    Use left + 1 < right, and justify the boundary
    '''
    def searchRange(self, nums: [int], target: int) -> [int]:
        if not nums: return -1,-1
        n = len(nums)
        return [self.find_first(nums, target), self.find_last(nums, target)]
        
    def find_first(self, nums, target):
        l, r = 0, len(nums) - 1
        while l + 1 < r:
            mid = (l + r) // 2
            num = nums[mid]
            if target == num:
                r = mid
            elif target < num:
                r = mid
            else:
                l = mid
        if nums[l] == target:
            return l 
        elif nums[r] == target:
            return r
        return -1
    
    def find_last(self, nums, target):
        l, r = 0, len(nums) - 1
        while l + 1 < r:
            mid = (l + r) // 2
            num = nums[mid]
            if target == num:
                l = mid
            elif target < num:
                r = mid
            else:
                l = mid
        if nums[r] == target:
            return r
        elif nums[l] == target:
            return l 
        return -1

# %% [markdown]
# 33.
# Search in Rotated Sorted Array
# There is an integer array nums sorted in ascending order (with distinct values).
#
# Prior to being passed to your function, nums is possibly rotated at an unknown pivot index k (1 <= k < nums.length) such that the resulting array is [nums[k], nums[k+1], ..., nums[n-1], nums[0], nums[1], ..., nums[k-1]] (0-indexed). For example, [0,1,2,4,5,6,7] might be rotated at pivot index 3 and become [4,5,6,7,0,1,2].
#
# Given the array nums after the possible rotation and an integer target, return the index of target if it is in nums, or -1 if it is not in nums.
#
# You must write an algorithm with O(log n) runtime complexity.
#
#
#
# Example 1:
#
# Input: nums = [4,5,6,7,0,1,2], target = 0
# Output: 4
# Example 2:
#
# Input: nums = [4,5,6,7,0,1,2], target = 3
# Output: -1
# Example 3:
#
# Input: nums = [1], target = 0
# Output: -1
#
#
# Constraints:
#
# 1 <= nums.length <= 5000
# -104 <= nums[i] <= 104
# All values of nums are unique.
# nums is an ascending array that is possibly rotated.
# -104 <= target <= 104

# %%
class Solution:
    ''' 
    Make one side monotonic, compare middle and left 
    '''
    def search(self, nums: [int], target: int) -> int:
        l, r = 0, len(nums) - 1
        L = nums[0]
        while l <= r:
            mid = (l + r) // 2
            if target == nums[mid]:
                return mid 

            if L <= nums[mid]:
                if L <= target < nums[mid]:
                    r = mid - 1
                else:
                    l = mid + 1
            else:
                if L > target > nums[mid]:
                    l = mid + 1
                else:
                    r = mid - 1

        return -1
